# %% [markdown]
# # Attention-BiLSTM Classifier evaluation

# %%
# Import code from file in upper directory
import sys, os
sys.path.append(os.getcwd() + os.sep + os.pardir)

from tweet_data import TweetsBaseDataset, get_mapping
from attn_lstm import AttentionBiLSTMClassifier
from train import load_model
from evaluate import predict_dataset

from collections import Counter
import numpy as np
from sklearn.metrics import f1_score, precision_score, recall_score, confusion_matrix
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# We start by instantiating a model with empty embeddings, and then loading the weights from an already trained model.

# %%
embeddings = np.empty((10002, 300), dtype=np.float32)
model = AttentionBiLSTMClassifier(embeddings)
model = load_model(model, '../runs/attbilstm-Sep28_14-29-40_gpu-deep-learner/best-ckpt.pt')

# %% [markdown]
# Now we load the dataset to evaluate the model.

# %%
test_set = TweetsBaseDataset.load('../data/test/us_test.set')
# Out:
# Loaded dataset with 50000 tweets, 10002 unique tokens

# %% [markdown]
# Since the model makes predictions for padded sequences in mini-batches, where sequences are sorted by length, the order can differ from the order of the tweets in the original dataset, so when predicting we also retrieve the indices that correspond to the line number of the tweet in the original dataset.

# %%
y_true, y_pred, indices = predict_dataset(model, test_set)

# %%
metrics = [f1_score, precision_score, recall_score]

for metric in metrics:
    print(metric.__name__ + ': {:.4f}'.format(metric(y_true, y_pred, average='macro')))
# Out:
# f1_score: 0.3378
# precision_score: 0.3505
# recall_score: 0.3353

# %% [markdown]
# These results are slightly higher than the results for the baselines, but they are also lower than those observed in [1], which used a similar model. The difference might be due to the smaller vocabulary size that we used (10,000 words).
#
# We can now examine the performance for each class. To gain further insight we will count the number of occurrences in the training set.

# %%
train_set = TweetsBaseDataset.load('../data/train/us_train.set')
# Out:
# Loaded dataset with 489609 tweets, 10002 unique tokens

# %% [markdown]
# For easier manipulation we will now create a DataFrame with emojis, counts and their respective metrics.

# %%
id_to_emoji = get_mapping('../data/mapping/us_mapping.txt')
ids = list(id_to_emoji.keys())
counter = Counter(train_set.labels)
scores = pd.DataFrame(list(id_to_emoji.values()), columns=['emoji'])
scores['count'] = [counter[i] for i in id_to_emoji]
# Add metrics
for i, metric in enumerate(metrics):
    scores[metric.__name__] = metric(y_true, y_pred, average=None)
    
scores = scores.sort_values(by='count', axis=0, ascending=False)

# %%
scores
# Out:
#    emoji   count  f1_score  precision_score  recall_score
# 0      ❤  106319  0.852122         0.864924      0.839693
# 1      😍   51267  0.368249         0.304465      0.465839
# 2      😂   50374  0.442837         0.406642      0.486105
# 3      💕   27030  0.243005         0.242633      0.243378
# 4      🔥   24404  0.527890         0.566667      0.494080
# 5      😊   23086  0.135517         0.124417      0.148791
# 6      😎   21103  0.202563         0.203227      0.201904
# 7      ✨   18130  0.299880         0.332889      0.272826
# 8      💙   16825  0.212689         0.240816      0.190445
# 9      😘   15959  0.167845         0.174472      0.161702
# 10     📷   15926  0.345817         0.279040      0.454609
# 11    🇺🇸   15168  0.631262         0.676643      0.591585
# 12     ☀   13699  0.657729         0.699643      0.620553
# 14     😉   13346  0.092857         0.111349      0.079632
# 15     💯   13238  0.255411         0.276735      0.237138
# 18     📸   13130  0.349738         0.441362      0.289615
# 16     😁   12924  0.088447         0.121951      0.069384
# 13     💜   12804  0.125824         0.189189      0.094255
# 17     🎄   12690  0.683560         0.669355      0.698382
# 19     😜   12187  0.073748         0.083024      0.066337

# %% [markdown]
# Is there a relationship between label frequency and model performance?

# %%
scores.drop('count', axis=1).plot.bar(title='Scores sorted by emoji count', figsize=(14, 5));

# %% [markdown]
# According to these results, even for unfrequent labels the model is able to obtain high scores for some emojis, such as emoji 17, which corresponds to the Christmas tree. We can hypothesize that emojis like the Christmas tree are easy to predict from the sole presence of particular words in the input, whereas for other emojis the relationship is not so obvious during prediction and might lead to similar labels in some cases. We can examine this using the confusion matrix. Due to the imbalance in the classes, this matrix is best visualized by taking a fractional power of the values:

# %%
confusion = confusion_matrix(y_true, y_pred)
plt.figure(figsize=(5,5))
plt.imshow(confusion**0.3, cmap='Blues')
plt.xticks(ids);
plt.yticks(ids);

# %% [markdown]
# We can see that:
#
# - When predicting a sun (12), the model often wrongly predicts a heart (0), and viceversa. The confusion with other labels is much lower, which explains why the F1 score for these two is the highest over all the emojis.
# - The camera (10) and its flashing version (18) are frequently mixed up. This might be because of their visual similarity, which results in people using both in similar tweets.
# - The 'winking face with tongue' emoji (19) has the lowest score and we see that it is easily confused with any other emoji, in particular with the 'face_with_tears_of_joy' (2).
#
# Let's now observe some failure cases for each emoji.

# %%
max_failures = 5
all_failures = [[] for i in ids]
predictions = [[] for i in ids]
inverse_vocab = {idx: word for word, idx in train_set.vocabulary.items()}

for i, y in enumerate(y_true):
    if sum([len(failures) for failures in all_failures]) == max_failures * len(ids):
        break
    
    if len(all_failures[y]) < max_failures and y != y_pred[i]:
        text_ids, _, _ = test_set[indices[i]]
        text_ids = text_ids.data.numpy()
        
        text = " ".join([inverse_vocab[idx] for idx in text_ids])
        
        all_failures[y].append(text)
        predictions[y].append(y_pred[i])
        
for i, failures in enumerate(all_failures):
    print('Emoji: {}'.format(id_to_emoji[i]))
    for j, fail in enumerate(failures):
        print('\t' + fail)
        print('\tPredicted: {}\n'.format(id_to_emoji[predictions[i][j]]))
    print('-'*100)
# Out:
# Emoji: ❤
# 	this is how we roll ! <hashtag> x men </hashtag> <hashtag> <UNK> </hashtag> <hashtag> storm </hashtag> <hashtag> <UNK> </hashtag> <hashtag> cosplay </hashtag> <hashtag> costumes </hashtag> <hashtag> halloween </hashtag> …
# 	Predicted: 😍
#
# 	just watched this film and it was very heart warming and a beautiful story • • <hashtag> film </hashtag> <hashtag> movie </hashtag> …
# 	Predicted: 💕
#
# 	merry merry christmas to you all . may god <UNK> our hearts with …
# 	Predicted: 🎄
#
# 	la playa ️ @ pleasure point park
# 	Predicted: ☀
#
# 	love my coworkers ! @ <UNK>
# 	Predicted: 😍
#
# ----------------------------------------------------------------------------------------------------
# Emoji: 😍
# 	reminiscing with the <hashtag> sunday best </hashtag> <hashtag> fashion design </hashtag> <hashtag> stage design </hashtag> <hashtag> set design </hashtag> <hashtag> <UNK> <UNK> </hashtag> <hashtag> event design </hashtag> …
# 	Predicted: ✨
#
# 	<allcaps> squad goals </allcaps> . <repeated> <hashtag> toronto bride </hashtag> <hashtag> toronto wedding </hashtag> <hashtag> hello <UNK> </hashtag> <hashtag> wedding party </hashtag> <hashtag> wedding florist </hashtag> …
# 	Predicted: 💕
#
# 	it ' s <hashtag> margarita monday </hashtag> ! come take a picture in our cute <hashtag> <UNK> </hashtag> frame @ <UNK> kitchen & cantina
# 	Predicted: 😎
#
# 	surprise 4 0 th <hashtag> birthday </hashtag> <hashtag> celebration </hashtag> for our bestie , tara ! we all love you so much happy …
# 	Predicted: 😘
#
# 	<number> years of our relationship have gone by and i still wonder how i got so lucky through the good …
# 	Predicted: 😂
#
# ----------------------------------------------------------------------------------------------------
# Emoji: 😂
# 	it ' s a tradition . have to toe - touch on a cliff <hashtag> dancer </hashtag> <hashtag> nyc to vegas </hashtag> <hashtag> summer 2017 </hashtag> <hashtag> take me back </hashtag> …
# 	Predicted: 😊
#
# 	about to <UNK> into tuesday . <hashtag> jeep </hashtag> <hashtag> jeep wave </hashtag> <hashtag> jeep life </hashtag> <hashtag> <UNK> </hashtag> <hashtag> jeep nation </hashtag> <hashtag> jeep porn </hashtag> …
# 	Predicted: 😎
#
# 	la <UNK> en <hashtag> miami </hashtag> down town en el real <UNK> <hashtag> la <UNK> en usa </hashtag> <hashtag> <UNK> </hashtag> <hashtag> florida </hashtag> <hashtag> usa </hashtag> …
# 	Predicted: 🇺🇸
#
# 	all <UNK> ! <repeated> the hot mess express jr . ! <repeated> so <elongated> cute though ! <hashtag> bailey bird </hashtag> @ fish <UNK> park
# 	Predicted: 😍
#
# 	i seriously have grandma hands ! but oh well got my nails done again and i kinda like it <hashtag> gold </hashtag> …
# 	Predicted: 😍
#
# ----------------------------------------------------------------------------------------------------
# Emoji: 💕
# 	custom color & <UNK> install <hashtag> hair <UNK> <UNK> </hashtag> <hashtag> queens stylist </hashtag> <hashtag> <UNK> pro </hashtag> @ the shop beauty …
# 	Predicted: 😍
#
# 	it ' s always wonderful to see sweet <UNK> ! she came in last week to get a fun haircut and warm …
# 	Predicted: 😊
#
# 	cocktail dress spaghetti <UNK> size s • m • l <UNK> buy the you love more at <user> your …
# 	Predicted: ✨
#
# 	q was meant to be a boss and that she shall be . i am that i am
# 	Predicted: 😂
#
# 	my niece <UNK> " <UNK> " she puts a smile on my face and just melts …
# 	Predicted: 😍
#
# ----------------------------------------------------------------------------------------------------
# Emoji: 🔥
# 	that ' s a . m . , you all ! <hashtag> i m not complaining </hashtag> <hashtag> just sayin </hashtag> <hashtag> florida life </hashtag> <hashtag> i <UNK> trade it </hashtag> …
# 	Predicted: 😎
#
# 	the <hashtag> sister stunt </hashtag> was mad real last night <hashtag> mia <UNK> <elongated> </hashtag> <hashtag> andrea <UNK> <elongated> </hashtag> <hashtag> denver queen </hashtag> <hashtag> <UNK> <elongated> life </hashtag> …
# 	Predicted: 😍
#
# 	- gains and more gains , i ’ m on to something . - <allcaps> b o o k </allcaps> your time with me , come get you …
# 	Predicted: 😜
#
# 	<hashtag> repost </hashtag> <user> ( <UNK> ) ・ ・ ・ <user> <hashtag> <UNK> </hashtag> <hashtag> cali </hashtag> <hashtag> kansas city </hashtag> <hashtag> <UNK> </hashtag> …
# 	Predicted: 📸
#
# 	vegan chicken ranch club s / o <UNK> <UNK> ' me to this spot . <hashtag> vegan </hashtag> <hashtag> vegan food porn </hashtag> …
# 	Predicted: 😍
#
# ----------------------------------------------------------------------------------------------------
# Emoji: 😊
# 	smiling from ear to ear these days because that ' s what life should be all about . …
# 	Predicted: ✨
#
# 	all you need is strong coffee and a short friday come see us this morning and get a …
# 	Predicted: 💕
#
# 	dim sum goodness <hashtag> dtla </hashtag> ( @ ocean seafood restaurant in los angeles , ca )
# 	Predicted: 😍
#
# 	always love being your plus one , thanks for a good night <user>
# 	Predicted: 😘
#
# 	welcome to new york ! @ times square , new york city
# 	Predicted: 🇺🇸
#
# ----------------------------------------------------------------------------------------------------
# Emoji: 😎
# 	even on fb . <hashtag> usa </hashtag> <hashtag> saint louis </hashtag> <hashtag> st louis </hashtag> <hashtag> best vape shop </hashtag> <hashtag> missouri </hashtag> <hashtag> webster groves </hashtag> <hashtag> <UNK> </hashtag> …
# 	Predicted: 🇺🇸
#
# 	range ready . ! <repeated> is <number> enough ? <repeated> i guess i could take the bucket <hashtag> pew pew </hashtag> @ accurate range , <allcaps> llc </allcaps>
# 	Predicted: 😂
#
# 	i could get use to this <hashtag> morning run </hashtag> <hashtag> beach bum </hashtag> @ kill devil hills …
# 	Predicted: 😂
#
# 	got me on lock down once again i needed a hug @ city of burlington , nj
# 	Predicted: 😍
#
# 	i was gone tell you i am <UNK> @ west bronx , bronx , new york
# 	Predicted: 💯
#
# ----------------------------------------------------------------------------------------------------
# Emoji: ✨
# 	mr <UNK> <UNK> in france no , i ’ m not a <percent> sure of the meaning behind this graphic tee , but …
# 	Predicted: 😁
#
# 	we been rocking , <UNK> , going all night @ the national orange show <allcaps> nos </allcaps> event center
# 	Predicted: 😎
#
# 	shopping during your lunch break makes wednesday feel like a friday ! @ <allcaps> dumbo </allcaps> , brooklyn
# 	Predicted: 😍
#
# 	<date> . today ' s hiked so fun with sweet friends and happy lovely two happy …
# 	Predicted: 💕
#
# 	a year full of lasts , senior homecoming @ franklin county seahawks , florida ( official )
# 	Predicted: 😜
#
# ----------------------------------------------------------------------------------------------------
# Emoji: 💙
# 	my reason <hashtag> can t stop won t stop </hashtag> till i am in my city driving a phantom please give my music a chance …
# 	Predicted: 🔥
#
# 	ohana means family and family means that no one gets left behind or forgotten lmao jk we are …
# 	Predicted: 😂
#
# 	i ain ' t even mad , this week has been full of love ! …
# 	Predicted: 😍
#
# 	our first vacation together @ disney ' s magic kingdom
# 	Predicted: 💕
#
# 	<UNK> week <hashtag> we fly </hashtag> <hashtag> cheese </hashtag> <hashtag> long hair do care </hashtag> <hashtag> curly </hashtag> <hashtag> <UNK> </hashtag> <hashtag> long beach </hashtag> <hashtag> <UNK> hoo </hashtag> @ rocks long beach
# 	Predicted: 😜
#
# ----------------------------------------------------------------------------------------------------
# Emoji: 😘
# 	it ' s the weekend , stay for a while . <repeated> <hashtag> new wave </hashtag> <hashtag> mind over matter </hashtag> <hashtag> luxury </hashtag> <hashtag> la living </hashtag> …
# 	Predicted: 😎
#
# 	my <number> in a <UNK> . <repeated> i can ’ t wait for many more just like it ! . <repeated> <hashtag> <UNK> </hashtag> …
# 	Predicted: 😍
#
# 	what goes up must come down . <hashtag> dc metro life </hashtag> ( pc to <user> ) @ washington metro
# 	Predicted: 📸
#
# 	miss you already <allcaps> nyc </allcaps> - see you in the fall <user> @ cha cha matcha
# 	Predicted: 😍
#
# 	<hashtag> cousins </hashtag> <hashtag> rhode island </hashtag> @ east providence , rhode island
# 	Predicted: ❤
#
# ----------------------------------------------------------------------------------------------------
# Emoji: 📷
# 	<UNK> hoo x score retail lounge [ shot by <user> <hashtag> charlotte </hashtag> <hashtag> clt </hashtag> <hashtag> hip hop </hashtag> …
# 	Predicted: 📸
#
# 	i am starting to love shooting in the dark <hashtag> brandon wolf el </hashtag> @ new york , new york
# 	Predicted: 😎
#
# 	ending the week and enjoying my day off like <hashtag> yas <elongated> </hashtag> . <repeated> <user>
# 	Predicted: 😊
#
# 	<number> - <number> <user> <UNK> <hashtag> black scale </hashtag> <hashtag> <UNK> <UNK> le </hashtag> <hashtag> <UNK> </hashtag> <hashtag> <UNK> ten years </hashtag> @ golden gate bridge
# 	Predicted: 😍
#
# 	a few more from mike ' s road trip to yellowstone ! <hashtag> yellowstone </hashtag> <hashtag> national park </hashtag> <hashtag> summer </hashtag> <hashtag> camping </hashtag> …
# 	Predicted: 😂
#
# ----------------------------------------------------------------------------------------------------
# Emoji: 🇺🇸
# 	saturday afternoon spent at <hashtag> point <UNK> </hashtag> at <hashtag> <UNK> beach </hashtag> to see all the <hashtag> <UNK> crab </hashtag> and …
# 	Predicted: 😊
#
# 	houston , we got a problem . <hashtag> <UNK> </hashtag> <hashtag> nasa </hashtag> <hashtag> houston </hashtag> <hashtag> <UNK> s </hashtag> <user>
# 	Predicted: 😜
#
# 	day <number> - a beautiful morning at san diego zoo , a global pioneer in conservation & <UNK> …
# 	Predicted: 😍
#
# 	my solo debut mixtape will be available to stream via soundcloud tomorrow <date> tracks …
# 	Predicted: 🔥
#
# 	west coast is the best coast ! good luck ladies ! <hashtag> repost </hashtag> <user>
# 	Predicted: 😘
#
# ----------------------------------------------------------------------------------------------------
# Emoji: ☀
# 	gone to soon . dang man it seems like i just met you . <allcaps> rip lil peep </allcaps> ️ <hashtag> <UNK> <UNK> mon ne </hashtag> …
# 	Predicted: ❤
#
# 	beautiful <UNK> night in <hashtag> <UNK> </hashtag> <hashtag> summer vacation 2017 </hashtag> ️ @ beach at …
# 	Predicted: ❤
#
# 	surround yourself with those who make you smile , build you up , and embrace the sunshine <user>
# 	Predicted: 💙
#
# 	film fest day <number> ️ <hashtag> s di ff </hashtag> @ <UNK> plaza park
# 	Predicted: ❤
#
# 	sunday morning walk through chelsea ️ <hashtag> selfie </hashtag> …
# 	Predicted: ❤
#
# ----------------------------------------------------------------------------------------------------
# Emoji: 💜
# 	star wars day ! may the force be with us . <hashtag> star wars </hashtag> <hashtag> hollywood studios </hashtag> <hashtag> may the force be with you </hashtag> <user>
# 	Predicted: 😎
#
# 	if you are in the la area , come by tomorrow and give what you can . <repeated> anything helps ! …
# 	Predicted: 😉
#
# 	your support matters - - <hashtag> repost </hashtag> <user> of <UNK> gives many gifts <UNK> …
# 	Predicted: ✨
#
# 	happy spirit week from your local <UNK> @ <UNK> high school
# 	Predicted: 💙
#
# 	<allcaps> happy november ladies </allcaps> @ atlanta , georgia
# 	Predicted: 😘
#
# ----------------------------------------------------------------------------------------------------
# Emoji: 😉
# 	even <UNK> can be <UNK> ! <hashtag> molly at <UNK> </hashtag> <hashtag> <UNK> vibes </hashtag> <hashtag> historic <UNK> </hashtag> <hashtag> quality touch <UNK> </hashtag> …
# 	Predicted: 😍
#
# 	. some days you need comfort food and you need someone else to prepare it for you . - thank you …
# 	Predicted: 😂
#
# 	all of the <number> <UNK> eve bread bake <UNK> le bistro chez les <UNK> . <repeated> pictured are …
# 	Predicted: ✨
#
# 	it took a fall festival , but she ' s finally behind bars <user> @ duluth fall festival
# 	Predicted: 😍
#
# 	happy birthday to one of the sweetest human <UNK> <user> also my crafty friend to many …
# 	Predicted: 💕
#
# ----------------------------------------------------------------------------------------------------
# Emoji: 💯
# 	<hashtag> <UNK> </hashtag> <hashtag> <UNK> </hashtag> <hashtag> <UNK> 2017 </hashtag> <UNK> <UNK> <UNK> | <allcaps> i tickets available </allcaps> <phone> . <repeated> <UNK> from …
# 	Predicted: 🔥
#
# 	good morning ! <repeated> even though " i know u do not like me . " <hashtag> we are the woes </hashtag> <hashtag> good lookin woe </hashtag> …
# 	Predicted: 😂
#
# 	let ’ s work ! schedule your appointment today ! thanks for your support <hashtag> <UNK> ain k </hashtag> <hashtag> tattoos </hashtag> <hashtag> ink </hashtag> …
# 	Predicted: ❤
#
# 	the eye candy is very nice in here ! ( @ big easy bar in university , fl )
# 	Predicted: 😊
#
# 	don ’ t let society tell you how to be . express yourself proudly @ hollywood
# 	Predicted: 😂
#
# ----------------------------------------------------------------------------------------------------
# Emoji: 😁
# 	i got the jr . <UNK> today <hashtag> <UNK> rehab </hashtag> <hashtag> pt </hashtag> <hashtag> pt central </hashtag> <hashtag> physical therapy </hashtag> <hashtag> women in medicine </hashtag> …
# 	Predicted: ❤
#
# 	countdown to <hashtag> <UNK> </hashtag> <hashtag> pen and ink </hashtag> <hashtag> <UNK> 2017 </hashtag> <hashtag> <UNK> </hashtag> <hashtag> <UNK> <UNK> </hashtag> <hashtag> <UNK> <UNK> </hashtag> …
# 	Predicted: 💯
#
# 	every . <repeated> damn . <repeated> day there is a lot of power in a smile ! <hashtag> dream <UNK> </hashtag> <hashtag> <UNK> </hashtag> …
# 	Predicted: 😍
#
# 	my grandparents they were <allcaps> huge </allcaps> role models in my life , especially my grandpa . he taught me how …
# 	Predicted: 😂
#
# 	<UNK> learning new <UNK> on aerial hoop @ prestige circus gym
# 	Predicted: ✨
#
# ----------------------------------------------------------------------------------------------------
# Emoji: 🎄
# 	i just fucking love <hashtag> christmas </hashtag> . ! <repeated> <user> <hashtag> yankees nation </hashtag> <hashtag> yankees </hashtag> …
# 	Predicted: 💙
#
# 	with these girls you can never have too much bling . ever . @ north naples , florida
# 	Predicted: ✨
#
# 	port <UNK> rocks thanks for the treat ! <repeated> <hashtag> love </hashtag> <hashtag> community </hashtag> <hashtag> gratitude </hashtag> <hashtag> little things </hashtag> …
# 	Predicted: 💕
#
# 	<allcaps> happy new year </allcaps> ! <repeated> <allcaps> love and peace </allcaps> ! <repeated> <hashtag> happy new year </hashtag> <hashtag> happy holidays </hashtag> …
# 	Predicted: ❤
#
# 	joy to the world @ cathedral of st . john the divine , <allcaps> nyc </allcaps>
# 	Predicted: ✨
#
# ----------------------------------------------------------------------------------------------------
# Emoji: 📸
# 	i just want you to listen ! • • photo cred : <UNK> <hashtag> mimi jean <UNK> </hashtag> # <number> <hashtag> artist </hashtag> <hashtag> music </hashtag> …
# 	Predicted: 😍
#
# 	can i do a throwback tuesday ? can not believe this was over a year ago <user>
# 	Predicted: 😂
#
# 	ignore the noise , focus on your work . <hashtag> perfect your craft </hashtag> athlete <user> …
# 	Predicted: 📷
#
# 	happy thanksgiving , ya <UNK> . <repeated> : : <UNK> . hutchinson @ thanksgiving ' s heroes
# 	Predicted: 📷
#
# 	straight business from here on out . <repeated> : <user> creative direction : <UNK> <user>
# 	Predicted: 📷
#
# ----------------------------------------------------------------------------------------------------
# Emoji: 😜
# 	rule number one <hashtag> couples goals </hashtag> <hashtag> monday </hashtag> <hashtag> monday motivation </hashtag> <hashtag> rule </hashtag> <hashtag> monday mood </hashtag> en atlanta , georgia
# 	Predicted: 😂
#
# 	nothing beats an authentic <allcaps> nola </allcaps> <UNK> <hashtag> essence festival </hashtag> <hashtag> big hair dont care </hashtag> <hashtag> nola </hashtag> @ new …
# 	Predicted: 😍
#
# 	<UNK> i feel like a <hashtag> <UNK> </hashtag> because i am constantly looking for your <hashtag> tweets </hashtag> because …
# 	Predicted: 😍
#
# 	crap i wanted to be home by midnight ( @ fat buddha in new york , ny )
# 	Predicted: 😂
#
# 	lucky as a seven , livin in heaven . <repeated> with my <UNK> delight <hashtag> nashville </hashtag> <user> <user>
# 	Predicted: 😍
#
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# ### References
#
# [1] Barbieri, Francesco, Miguel Ballesteros, and Horacio Saggion. "Are Emojis Predictable?." arXiv preprint arXiv:1702.07285 (2017).
